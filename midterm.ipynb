# %% [markdown]
# ### <u>Midterm</u>

# %% [markdown]
# The Daily Mash, a satirical online news outlet
# - scraped via sitemap xml NOT paginated scraping
# - to respect site's scraping policy
# - compare by categories rather than general...politics to politics, same time period too
